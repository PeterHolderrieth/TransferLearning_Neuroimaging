# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_step=np.array([[0.1, 3.79453],
[0.2125, 3.37630],
[0.325,3.37772],
[0.4375, 3.23194],
[0.55,  3.25705],
[0.6625, 3.29864],
[0.775,3.31344],
[0.8875,3.30285],
[1.0,3.24012]])

# %%
grid=x_step[:,0]
results_step=x_step[:,1]
n_total_samples_oasis=355
samples_grid_oasis=np.round(n_total_samples_oasis*grid)

# %%
x_final=np.array([[0.1,4.59166],
  [0.2125,4.05101],
  [0.325,3.83080],
  [0.4375,3.58980],
  [0.55,3.56908],
  [0.6625,3.58234],
  [0.775,3.51972],
  [0.8875,3.52138],
  [1.0, 3.5393]])
results_final=x_final[:,1]

x_abide_final=np.array([[0.1,0.69771],
[0.2125,0.67443],
[0.325,0.68301],
[0.4375,0.71977],
[0.55,0.71936],
[0.6625,0.70752],
[0.775,0.71569],
[0.8875,0.72059],
[1.0,0.71691]])

x_abide_full=np.array(
[[0.1,0.53268],
[0.2125,0.72876],
[0.325, 0.50817],
[0.4375,0.60907],
[0.55,0.64093],
[0.6625,0.58701],
[0.775,0.72998],
[0.8875,0.77451],
[1.0,0.757]])

results_full_abide=x_abide_full[:,1]
results_full_abide=

# %%
fig,ax=plt.subplots(ncols=2,nrows=1,figsize=(10,5))
ax[0].plot(samples_grid_oasis,results_step,label='full')
ax[0].scatter(samples_grid_oasis,results_step)
ax[0].plot(samples_grid_oasis,results_final,label='final')
ax[0].scatter(samples_grid_oasis,results_final)

ax[0].set_xlabel("N train samples")
ax[0].set_ylabel("MAE")
ax[0].set_title("OASIS age")
ax[0].legend()

n_total_samples_abide=537
samples_grid_abide=np.round(n_total_samples_abide*grid)
results_final_abide=x_abide_final[:,1]

# ax[1].plot(samples_grid_abide,results_step_abide,label='full')
ax[1].plot(samples_grid_abide,x_abide_full[:,1],label='full')
ax[1].scatter(samples_grid_abide,x_abide_full[:,1])
ax[1].plot(samples_grid_abide,results_final_abide,label='final')
ax[1].scatter(samples_grid_abide,results_final_abide)
ax[1].set_xlabel("N train samples")
ax[1].set_ylabel("accuracy")
ax[1].set_title("ABIDE sex")
ax[1].legend()

plt.savefig("visualization/plots/data_scarcity_plot.png")
